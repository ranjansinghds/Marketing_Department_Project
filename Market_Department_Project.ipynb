# %% [markdown]
# # TASK #1: UNDERSTAND THE PROBLEM STATEMENT AND BUSINESS CASE

# %% [markdown]
# ![Market Department Png](Market_Department_Png/download.png)

# %% [markdown]
# ![Market Department Png](Market_Department_Png/download_1.png)

# %% [markdown]
# ![Market Department Png](Market_Department_Png/download_2.png)

# %% [markdown]
# ![Market Department Png](Market_Department_Png/download_3.png)

# %% [markdown]
# ![Market Department Png](Market_Department_Png/download_4.png)

# %% [markdown]
# ![Market Department Png](Market_Department_Png/download_5.png)

# %% [markdown]
# ![Market Department Png](Market_Department_Png/download_6.png)

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/arjunbhasin2013/ccdata

# %% [markdown]
# # TASK #2: IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the dataset
creditcard_df = pd.read_csv('Marketing_data.csv')

# %% [markdown]
# # Dataset feature information
# * CUSTID: Identification of Credit Card holder
# * BALANCE: Balance amount left in customer's account to make purchases
# * BALANCE_FREQUENCY: How frequently the Balance is updated, score between 0 and 1 (1 = frequently updated, 0 = not frequently updated)
# * PURCHASES: Amount of purchases made from account
# * ONEOFFPURCHASES: Maximum purchase amount done in one-go
# * INSTALLMENTS_PURCHASES: Amount of purchase done in installment
# * CASH_ADVANCE: Cash in advance given by the user
# * PURCHASES_FREQUENCY: How frequently the Purchases are being made, score between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# * ONEOFF_PURCHASES_FREQUENCY: How frequently Purchases are happening in one-go (1 = frequently purchased, 0 = not frequently purchased)
# * PURCHASES_INSTALLMENTS_FREQUENCY: How frequently purchases in installments are being done (1 = frequently done, 0 = not frequently done)
# * CASH_ADVANCE_FREQUENCY: How frequently the cash in advance being paid
# * CASH_ADVANCE_TRX: Number of Transactions made with "Cash in Advance"
# * PURCHASES_TRX: Number of purchase transactions made
# * CREDIT_LIMIT: Limit of Credit Card for user
# * PAYMENTS: Amount of Payment done by user
# * MINIMUM_PAYMENTS: Minimum amount of payments made by user
# * PRC_FULL_PAYMENT: Percent of full payment paid by user
# * TENURE: Tenure of credit card service for user

# %%
# checking head of the dataset
creditcard_df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
# checking tail of the dataset
creditcard_df.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 8945  325.594462         48.886365              0.50       6
# 8946  275.861322               NaN              0.00       6
# 8947   81.270775         82.418369              0.25       6
# 8948   52.549959         55.755628              0.25       6
# 8949   63.165404         88.288956              0.00       6

# %%
# checking full info of our dataset
creditcard_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
# checking the statistics of our dataset
creditcard_df.describe()

# Mean balance is $1564
# Balance frequency is frequently updated on average ~0.9
# Purchases average is $1000
# One off purchase average is ~$600
# Average purchase frequency is around 0.5
# Average ONEOFF_PURCHASES_FREQUENCY, PURCHASES_INSTALLMENTS_FREQUENCY	CASH_ADVANCE_FREQUENCY are generally low
# Average credit card limit  is ~$4500
# Average percent of full payment is 15%
# Average tenure is 11 years
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %%
# Let's see who made one off purchase of $40761!
creditcard_df[creditcard_df['ONEOFF_PURCHASES'] == 40761.250000]
# Out:
#     CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 550  C10574  11547.52001                1.0   49039.57          40761.25
#
#      INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 550                 8278.32    558.166886                  1.0
#
#      ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 550                         1.0                          0.916667
#
#      CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 550                0.083333                 1            101       22500.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 550  46930.59824       2974.069421              0.25      12

# %%
# Let's see who made max CASH_ADVANCE
creditcard_df['CASH_ADVANCE'].max()
# Out:
# 47137.21176

# %%
# Let's see who made CASH_ADVANCE of $47137!
creditcard_df[creditcard_df['CASH_ADVANCE'] == 47137.211760]	

# This customer made 123 cash advance transations!
# Never paid credit card in full
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 2159  C12226  10905.05381                1.0     431.93             133.5
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 2159                  298.43   47137.21176             0.583333
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 2159                        0.25                               0.5
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 2159                     1.0               123             21       19600.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 2159  39048.59762       5394.173671               0.0      12

# %% [markdown]
# # TASK #3: VISUALIZE AND EXPLORE DATASET

# %%
# Let's see if we have any missing data
plt.figure(figsize=(10,6))
sns.heatmap(creditcard_df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
# Out:
# <Axes: >

# %%
# checking the missing data
creditcard_df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Fill up the missing elements with mean of the 'MINIMUN_PAYMENT'
creditcard_df['MINIMUM_PAYMENTS'] = creditcard_df['MINIMUM_PAYMENTS'].fillna(creditcard_df['MINIMUM_PAYMENTS'].mean())

# this is the second method
# (creditcard_df.loc[(creditcard_df['MINIMUM_PAYMENTS'].isnull() == True), 'MINIMUM_PAYMENT']) = creditcard_df['MINIMUM_PAYMENTS'].mean()

# %%
# Fill  up the missing elements with mean of the 'CREDIT_LIMIT'
creditcard_df['CREDIT_LIMIT'] = creditcard_df['CREDIT_LIMIT'].fillna(creditcard_df['CREDIT_LIMIT'].mean())

# %%
# checking the missing data again after adjustmet
creditcard_df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# Let's see if we have duplicated entries in the data
creditcard_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Let's drop Customer ID since it has no meaning here
creditcard_df.drop(['CUST_ID'], axis=1, inplace= True)

# %%
creditcard_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
# checking the columns names
creditcard_df.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %%
# distplot combines the matplotlib.hist function with seaborn kdeplot()
# KDE Plot represents the Kernel Density Estimate
# KDE is used for visualizing the Probability Density of a continuous variable.
# KDE demonstrates the probability density at different values in a continuous variable.

# Mean of balance is $1500
# 'Balance_Frequency' for most customers is updated frequently ~1
# For 'PURCHASES_FREQUENCY', there are two distinct group of customers
# For 'ONEOFF_PURCHASES_FREQUENCY' and 'PURCHASES_INSTALLMENT_FREQUENCY' most users don't do one off puchases or installment purchases frequently
# Very small number of customers pay their balance in full 'PRC_FULL_PAYMENT'~0
# Credit limit average is around $4500
# Most customers are ~11 years tenure

plt.figure(figsize=(12,50))
for i in range(len(creditcard_df.columns)):
    plt.subplot(len(creditcard_df.columns), 1, i + 1)
    sns.histplot(creditcard_df.iloc[:, i], bins=30, stat='density', kde=True, color='r')
    sns.kdeplot(creditcard_df.iloc[:, i], color='b', lw=3)

    plt.title(creditcard_df.columns[i])

plt.tight_layout()

# %%
# Correlation between 'PURCHASES' and ONEOFF_PURCHASES & INSTALLMENT_PURCHASES
# Trend between 'PURCHASES' and 'CREDIT_LIMIT' & 'PAYMENT'

correlations = creditcard_df.corr()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(correlations, annot=True )

# %%
# 'PURCHASES' have high correlation between one-off purchases, 'installment purchases, purchase transactions, credit limit and payments.
# Strong Positive Correlation between 'PURCHASES_FREQUENCY' and 'PURCHASES_INSTALLMENT_FREQUENCY'

# %% [markdown]
# # TASK #4: FIND THE OPTIMAL NUMBER OF CLUSTERS USING ELBOW METHOD

# %%
# Let's scale the data first
from sklearn.preprocessing import StandardScaler, normalize

scaler = StandardScaler()

creditcard_df_scaled = scaler.fit_transform(creditcard_df)

# %%
creditcard_df_scaled.shape
# Out:
# (8950, 17)

# %%
creditcard_df_scaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]], shape=(8950, 17))

# %%
from sklearn.cluster import KMeans

score_1 = []

range_values = range(1,20)

for i in range_values:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(creditcard_df_scaled)
    score_1.append(kmeans.inertia_)

# %%
plt.plot(range(1,20), score_1, 'bx-')
plt.title('Finding the right number of clusters')
plt.xlabel('Clusters')
plt.ylabel('Score WCSS')
# Out:
# Text(0, 0.5, 'Score WCSS')

# %%
# From this we can observe that, 4th cluster seems to be forming the elbow of the curve.
# However, the values does not reduce linearly until 8th cluster.
# Let's choose the number of clusters to be 7 or 8

# %% [markdown]
# # TASK #5: APPLY K-MEANS METHOD

# %%
kmeans = KMeans(n_clusters=8)
kmeans.fit(creditcard_df_scaled)
labels = kmeans.labels_

# %%
labels
# Out:
# array([5, 2, 4, ..., 7, 5, 4], shape=(8950,), dtype=int32)

# %%
kmeans.cluster_centers_.shape
# Out:
# (8, 17)

# %%
cluster_clusters = pd.DataFrame(data=kmeans.cluster_centers_, columns=creditcard_df.columns)

# %%
cluster_clusters
# Out:
#     BALANCE BALANCE_FREQUENCY  PURCHASES ONEOFF_PURCHASES  \
# 0  0.887587          0.469939   2.263357         1.784901
# 1 -0.199570          0.364237  -0.047514        -0.214175
# 2  1.650741          0.374810  -0.218307        -0.148875
# 3 -0.695934         -2.193782  -0.324647        -0.235585
# 4 -0.174252          0.388092   0.427683         0.588793
# 5  0.004092          0.372080  -0.370779        -0.250557
# 6  1.923051          0.337717  11.212042        10.600367
# 7 -0.707015          0.015902  -0.052859        -0.263424
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0               2.072584    -0.193073            1.159672
# 1               0.281200    -0.304418            0.929886
# 2              -0.242732     2.033774           -0.491799
# 3              -0.334680    -0.297800           -0.610297
# 4              -0.070529    -0.340514            0.912712
# 5              -0.416289    -0.047344           -0.916379
# 6               7.033118     0.419625            1.046983
# 7               0.358461    -0.451486            0.867685
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   1.630869                         1.209147
# 1                  -0.313444                         1.121017
# 2                  -0.197259                        -0.441704
# 3                  -0.435943                        -0.496695
# 4                   1.911196                        -0.014088
# 5                  -0.421470                        -0.801874
# 6                   1.915501                         0.981334
# 7                  -0.401387                         1.004019
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX CREDIT_LIMIT  \
# 0              -0.298448        -0.205672      2.745731     1.255246
# 1              -0.351850        -0.290597      0.176001    -0.306067
# 2               1.945842         1.923539     -0.275088     1.016216
# 3              -0.471650        -0.348911     -0.439881    -0.224436
# 4              -0.413061        -0.332631      0.485561     0.363193
# 5               0.186046         0.006290     -0.502856    -0.334229
# 6              -0.258912         0.061229      5.362438     3.044064
# 7              -0.647511        -0.463411      0.051431    -0.203582
#
#    PAYMENTS MINIMUM_PAYMENTS PRC_FULL_PAYMENT    TENURE
# 0  1.265158         0.424154         0.290706  0.333068
# 1 -0.203922         0.068534        -0.342083  0.107045
# 2  0.795816         0.492277        -0.393720 -0.092399
# 3 -0.219626        -0.251754         0.073180 -0.156214
# 4  0.062205        -0.167639         0.339072  0.189123
# 5 -0.261064        -0.023904        -0.452313 -0.015837
# 6  8.098975         1.120318         1.110132  0.310863
# 7 -0.255926        -0.295030         2.133058 -0.290711

# %%
# In order to understand what these numbers mean, Let's perform inverse transformation
cluster_clusters = scaler.inverse_transform(cluster_clusters)
cluster_clusters = pd.DataFrame(data = cluster_clusters, columns=[creditcard_df.columns])
cluster_clusters

# First Customers cluster (Transactors): Those are customers who pay least amount of intrerest charges and careful with their money, Cluster with lowest balance ($103) and cash advance ($302), Percentage of full payment = 24%
# Second customers cluster (revolvers) who use credit card as a loan (most lucrative sector): highest balance ($5007) and cash advance (~$8910), low purchase frequency, high cash advance frequency (0.65), high cash advance transactions (28) and low percentage of full payment (8%)
# Third customer cluster (VIP/Prime): high credit limit $13K and highest percentage of full payment, target for increase credit limit and increase spending habits
# Fourth customer cluster (low tenure): these are customers with low tenure (7 years), low balance
# Out:
#        BALANCE BALANCE_FREQUENCY     PURCHASES ONEOFF_PURCHASES  \
# 0  3411.912572          0.988595   5838.901062      3555.007436
# 1  1149.085778          0.963555    901.690714       236.951349
# 2  5000.353896          0.966060    536.788292       345.334966
# 3   115.946002          0.357584    309.590868       201.415149
# 4  1201.783697          0.969206   1916.955591      1569.713420
# 5  1572.991687          0.965413    211.028830       176.563347
# 6  5567.142164          0.957273  24957.905000     18186.875667
# 7    92.882778          0.881038    890.270694       155.207107
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0            2285.279307   573.987782            0.955783
# 1             665.353251   340.491606            0.863559
# 2             191.568337  5243.790646            0.292968
# 3             108.421008   354.370254            0.245409
# 4             347.289241   264.797459            0.856666
# 5              34.622593   879.587514            0.122564
# 6            6771.029333  1858.844605            0.910556
# 7             735.219319    32.083301            0.838594
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.688978                         0.844983
# 1                   0.108951                         0.809958
# 2                   0.143611                         0.188893
# 3                   0.072407                         0.167038
# 4                   0.772605                         0.358838
# 5                   0.076725                         0.045752
# 6                   0.773889                         0.754444
# 7                   0.082716                         0.763460
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX  CREDIT_LIMIT  \
# 0               0.075422         1.845266     82.958430   9061.547344
# 1               0.064735         1.265714     19.084571   3380.853102
# 2               0.524527        16.375566      7.872172   8191.860346
# 3               0.040762         0.867769      3.776033   3677.858590
# 4               0.052486         0.978866     26.779059   5815.895555
# 5               0.172374         3.291755      2.210712   3278.388537
# 6               0.083333         3.666667    148.000000  15570.000000
# 7               0.005571         0.086387     15.988220   3753.733341
#
#        PAYMENTS MINIMUM_PAYMENTS PRC_FULL_PAYMENT     TENURE
# 0   5395.653527      1852.679011         0.238741  11.963048
# 1   1142.808740      1023.922576         0.053661  11.660571
# 2   4036.954030      2011.437378         0.038558  11.393665
# 3   1097.347933       277.505498         0.175118  11.308264
# 4   1913.221776       473.530263         0.252887  11.770413
# 5    977.387913       808.499816         0.021421  11.496124
# 6  25178.882690      3475.059479         0.478409  11.933333
# 7    992.262559       176.652453         0.777597  11.128272

# %%
labels.shape
# Out:
# (8950,)

# %%
labels.max()
# Out:
# np.int32(7)

# %%
labels.min()
# Out:
# np.int32(0)

# %%
labels
# Out:
# array([5, 2, 4, ..., 7, 5, 4], shape=(8950,), dtype=int32)

# %%
# concatenate the clusters labels to our original dataframe
creditcard_df_Cluster = pd.concat([creditcard_df, pd.DataFrame({'cluster':labels})], axis=1)
creditcard_df_Cluster.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0   201.802084        139.509787          0.000000      12        5
# 1  4103.032597       1072.340217          0.222222      12        2
# 2   622.066742        627.284787          0.000000      12        4
# 3     0.000000        864.206542          0.000000      12        5
# 4   678.334763        244.791237          0.000000      12        5

# %%
# Plot the histogram of the various clusters
for i in creditcard_df.columns:
    plt.figure(figsize=(35,5))

    for j in range(8):
        plt.subplot(1,8, j+1)
        cluster = creditcard_df_Cluster[creditcard_df_Cluster['cluster'] == j]
        cluster[i].hist(bins = 20)
        plt.title(f'{i} \nCluster {j}')

    plt.show()

# %% [markdown]
# # TASK 6: APPLY PRINCIPAL COMPONENT ANALYSIS AND VISUALIZE THE RESULTS

# %%
# Obtain the principal components
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
principal_com = pca.fit_transform(creditcard_df_scaled)
principal_com
# Out:
# array([[-1.68222026, -1.07645061],
#        [-1.1382949 ,  2.50647666],
#        [ 0.96968401, -0.3835203 ],
#        ...,
#        [-0.92620364, -1.8107856 ],
#        [-2.33655167, -0.65796601],
#        [-0.55642216, -0.40046712]], shape=(8950, 2))

# %%
# Create  a dataframe with the two components
pca_df = pd.DataFrame(data=principal_com, columns=['pca1', 'pca2'])
pca_df.head()
# Out:
#        pca1      pca2
# 0 -1.682220 -1.076451
# 1 -1.138295  2.506477
# 2  0.969684 -0.383520
# 3 -0.873628  0.043166
# 4 -1.599434 -0.688581

# %%
# Concatenate the clusters labels to the dataframe
pca_df = pd.concat([pca_df, pd.DataFrame({'cluster':labels})], axis=1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -1.682220 -1.076451        5
# 1 -1.138295  2.506477        2
# 2  0.969684 -0.383520        4
# 3 -0.873628  0.043166        5
# 4 -1.599434 -0.688581        5

# %%
plt.figure(figsize=(10,10))
sns.set_style('dark')
sns.scatterplot(x='pca1', y='pca2', hue='cluster', data=pca_df, palette=['red','green','blue','pink','yellow','grey','purple','black'])

# %% [markdown]
# # TASK #7: APPLY AUTOENCODERS (PERFORM DIMENSIONALITY REDUCTION USING AUTOENCODERS)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from keras.optimizers import SGD

# %%
input_df = Input(shape=(17,))

x = Dense(7, activation='relu')(input_df)
x = Dense(500, activation='relu', kernel_initializer='glorot_uniform')(x)
x = Dense(500, activation='relu', kernel_initializer='glorot_uniform')(x)
x = Dense(2000, activation='relu', kernel_initializer='glorot_uniform')(x)

encoded = Dense(10, activation='relu', kernel_initializer='glorot_uniform')(x)

x = Dense(2000, activation='relu', kernel_initializer='glorot_uniform')(encoded)
x = Dense(500, activation='relu', kernel_initializer='glorot_uniform')(x)

decoded = Dense(17, kernel_initializer='glorot_uniform')(x)

# Autoencoder
autoencoder = Model(input_df, outputs=decoded)

# Encoder
encoder = Model(input_df, outputs=encoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# %%
creditcard_df_scaled.shape
# Out:
# (8950, 17)

# %%
autoencoder.fit(creditcard_df_scaled, creditcard_df_scaled, batch_size=128, epochs=25, verbose=1)
# Out:
# Epoch 1/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - loss: 0.5565
# Epoch 2/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.3004
# Epoch 3/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.2353
# Epoch 4/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.2052
# Epoch 5/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.1828
# Epoch 6/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1763
# Epoch 7/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1592
# Epoch 8/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1447
# Epoch 9/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.1367
# Epoch 10/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1211
# Epoch 11/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1138
# Epoch 12/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.1033
# Epoch 13/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0974
# Epoch 14/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0925
# Epoch 15/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0858
# Epoch 16/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0791
# Epoch 17/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0751
# Epoch 18/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0705
# Epoch 19/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0686
# Epoch 20/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0631
# Epoch 21/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0611
# Epoch 22/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0591
# Epoch 23/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0555
# Epoch 24/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0573
# Epoch 25/25
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0551

# %%
# checking the Autoencoder Architecture
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 17)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 7)              │           126 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 500)            │         4,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 500)            │       250,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2000)           │     1,002,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │        20,010 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 500)            │         5,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 17)             │         8,517 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,871,961 (14.77 MB)
#  Trainable params: 1,290,653 (4.92 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2,581,308 (9.85 MB)

# %%
predictions = encoder.predict(creditcard_df_scaled)
# Out:
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
predictions
# Out:
# array([[ 1.9253491 ,  1.0004863 ,  1.1540638 , ...,  0.24698249,
#          1.0335387 ,  2.4006393 ],
#        [ 5.541833  ,  1.0843489 ,  1.0784311 , ...,  0.        ,
#          2.6270475 ,  4.4236035 ],
#        [ 3.2648952 ,  1.1123145 ,  0.6649223 , ...,  5.353607  ,
#          0.        ,  1.1476214 ],
#        ...,
#        [ 0.30983275,  4.214024  ,  1.7274722 , ...,  3.5657327 ,
#          7.6091604 ,  4.5982914 ],
#        [ 2.269193  ,  3.9029634 ,  0.38956967, ...,  3.0040972 ,
#          7.4899974 ,  5.586392  ],
#        [ 2.720509  ,  3.6863444 ,  1.1301979 , ...,  7.470421  ,
#         10.719131  ,  7.4918065 ]], shape=(8950, 10), dtype=float32)

# %%
predictions.shape
# Out:
# (8950, 10)

# %%
# optimal number of cluster
# kmeans
# PCA

score_2 = []

range_values = range(1,20)

for i in range_values:
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(predictions)
    score_2.append(kmeans.inertia_)

plt.plot(score_2, 'bx-')
plt.title('Finding right number of clusters')
plt.xlabel('Clusters')
plt.ylabel('Scores')
plt.show()

# %%
#  checking both scores_1 and scores_2
# in bx argument b represent the color so we are giving a different color as red and green so we removed b

plt.plot(score_1, 'x-', color='r')
plt.plot(score_2, 'x-', color='g')

# %%
kmeans = KMeans(4)
kmeans.fit(predictions)
labels = kmeans.labels_

# %%
df_cluster_dr = pd.concat([creditcard_df, pd.DataFrame({'cluster': labels})], axis=1)
df_cluster_dr.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0   201.802084        139.509787          0.000000      12        1
# 1  4103.032597       1072.340217          0.222222      12        3
# 2   622.066742        627.284787          0.000000      12        1
# 3     0.000000        864.206542          0.000000      12        1
# 4   678.334763        244.791237          0.000000      12        1

# %%
pca = PCA(n_components=2)
prin_comp = pca.fit_transform(predictions)
pca_df = pd.DataFrame(data= prin_comp, columns=['pca1', 'pca2'])

# %%
pca_df = pd.concat([pca_df, pd.DataFrame({'cluster': labels})], axis=1)
pca_df.head()
# Out:
#        pca1      pca2  cluster
# 0 -3.261201  0.184233        1
# 1  2.507551  1.655423        3
# 2 -1.153855 -1.979921        1
# 3  0.014015 -0.221795        1
# 4 -3.644780  0.350985        1

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='pca1', y='pca2', hue='cluster', data=pca_df, palette=['red','green','blue','yellow'])
# Out:
# <Axes: xlabel='pca1', ylabel='pca2'>

# %% [markdown]
# # Well Done!
